-- %%
%CREATE movies_db.db

-- %%
-- Create the Genres table
CREATE TABLE Genres (
    GenreID INTEGER PRIMARY KEY,
    GenreName TEXT NOT NULL
);

-- %%
-- Create the Movies table
CREATE TABLE Movies (
    MovieID INTEGER PRIMARY KEY,
    Title TEXT NOT NULL,
    ReleaseYear INTEGER,
    Duration INTEGER, -- in minutes
    Director TEXT
);

-- %%
-- Create the MovieGenres table
CREATE TABLE MovieGenres (
    MovieGenreID INTEGER PRIMARY KEY,
    MovieID INTEGER,
    GenreID INTEGER,
    FOREIGN KEY (MovieID) REFERENCES Movies(MovieID),
    FOREIGN KEY (GenreID) REFERENCES Genres(GenreID)
);

-- %%
INSERT INTO Movies (MovieID, Title, ReleaseYear, Duration, Director) VALUES
(1, 'The Shawshank Redemption', 1994, 142, 'Frank Darabont'),
(2, 'The Godfather', 1972, 175, 'Francis Ford Coppola'),
(3, 'The Dark Knight', 2008, 152, 'Christopher Nolan'),
(4, 'The Godfather Part II', 1974, 202, 'Francis Ford Coppola'),
(5, '12 Angry Men', 1957, 96, 'Sidney Lumet'),
(6, 'Schindler''s List', 1993, 195, 'Steven Spielberg'),
(7, 'The Lord of the Rings: The Return of the King', 2003, 201, 'Peter Jackson'),
(8, 'Pulp Fiction', 1994, 154, 'Quentin Tarantino'),
(9, 'The Good, the Bad and the Ugly', 1966, 178, 'Sergio Leone'),
(10, 'Fight Club', 1999, 139, 'David Fincher'),
(11, 'Forrest Gump', 1994, 142, 'Robert Zemeckis'),
(12, 'Inception', 2010, 148, 'Christopher Nolan'),
(13, 'The Lord of the Rings: The Fellowship of the Ring', 2001, 178, 'Peter Jackson'),
(14, 'Star Wars: Episode V - The Empire Strikes Back', 1980, 124, 'Irvin Kershner'),
(15, 'The Matrix', 1999, 136, 'Lana Wachowski, Lilly Wachowski'),
(16, 'Goodfellas', 1990, 146, 'Martin Scorsese'),
(17, 'One Flew Over the Cuckoo''s Nest', 1975, 133, 'Milos Forman'),
(18, 'Seven Samurai', 1954, 207, 'Akira Kurosawa'),
(19, 'Se7en', 1995, 127, 'David Fincher'),
(20, 'It''s a Wonderful Life', 1946, 130, 'Frank Capra'),
(21, 'The Silence of the Lambs', 1991, 118, 'Jonathan Demme'),
(22, 'City of God', 2002, 130, 'Fernando Meirelles, Kátia Lund'),
(23, 'Saving Private Ryan', 1998, 169, 'Steven Spielberg'),
(24, 'Interstellar', 2014, 169, 'Christopher Nolan'),
(25, 'The Green Mile', 1999, 189, 'Frank Darabont'),
(26, 'Life Is Beautiful', 1997, 116, 'Roberto Benigni'),
(27, 'Star Wars: Episode IV - A New Hope', 1977, 121, 'George Lucas'),
(28, 'Terminator 2: Judgment Day', 1991, 137, 'James Cameron'),
(29, 'Back to the Future', 1985, 116, 'Robert Zemeckis'),
(30, 'Spirited Away', 2001, 125, 'Hayao Miyazaki'),
(31, 'The Pianist', 2002, 150, 'Roman Polanski'),
(32, 'The Departed', 2006, 151, 'Martin Scorsese'),
(33, 'Gladiator', 2000, 155, 'Ridley Scott'),
(34, 'The Prestige', 2006, 130, 'Christopher Nolan'),
(35, 'The Lion King', 1994, 88, 'Roger Allers, Rob Minkoff'),
(36, 'Memento', 2000, 113, 'Christopher Nolan'),
(37, 'Apocalypse Now', 1979, 147, 'Francis Ford Coppola'),
(38, 'Alien', 1979, 117, 'Ridley Scott'),
(39, 'The Great Dictator', 1940, 125, 'Charles Chaplin'),
(40, 'Sunset Blvd.', 1950, 110, 'Billy Wilder'),
(41, 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 1964, 95, 'Stanley Kubrick'),
(42, 'The Shining', 1980, 146, 'Stanley Kubrick'),
(43, 'WALL·E', 2008, 98, 'Andrew Stanton'),
(44, 'American Beauty', 1999, 122, 'Sam Mendes'),
(45, 'The Dark Knight Rises', 2012, 164, 'Christopher Nolan'),
(46, 'Oldboy', 2003, 120, 'Park Chan-wook'),
(47, 'Princess Mononoke', 1997, 134, 'Hayao Miyazaki'),
(48, 'Once Upon a Time in America', 1984, 229, 'Sergio Leone'),
(49, 'Witness for the Prosecution', 1957, 116, 'Billy Wilder'),
(50, 'Das Boot', 1981, 149, 'Wolfgang Petersen');

-- %%
INSERT INTO Genres (GenreID, GenreName) VALUES
(1, 'Drama'),
(2, 'Crime'),
(3, 'Action'),
(4, 'Thriller'),
(5, 'Adventure'),
(6, 'Sci-Fi'),
(7, 'Western'),
(8, 'Biography'),
(9, 'Fantasy'),
(10, 'Mystery'),
(11, 'War'),
(12, 'Animation'),
(13, 'Comedy'),
(14, 'Family'),
(15, 'Romance'),
(16, 'Horror');

-- %%
INSERT INTO MovieGenres (MovieGenreID, MovieID, GenreID) VALUES
(1, 1, 1),   -- The Shawshank Redemption -> Drama
(2, 2, 1),   -- The Godfather -> Drama
(3, 2, 2),   -- The Godfather -> Crime
(4, 3, 3),   -- The Dark Knight -> Action
(5, 3, 2),   -- The Dark Knight -> Crime
(6, 4, 1),   -- The Godfather Part II -> Drama
(7, 4, 2),   -- The Godfather Part II -> Crime
(8, 5, 1),   -- 12 Angry Men -> Drama
(9, 6, 1),   -- Schindler's List -> Drama
(10, 7, 5),  -- The Lord of the Rings: The Return of the King -> Adventure
(11, 7, 1),  -- The Lord of the Rings: The Return of the King -> Drama
(12, 8, 1),  -- Pulp Fiction -> Drama
(13, 8, 2),  -- Pulp Fiction -> Crime
(14, 9, 7),  -- The Good, the Bad and the Ugly -> Western
(15, 10, 1), -- Fight Club -> Drama
(16, 11, 1), -- Forrest Gump -> Drama
(17, 12, 3), -- Inception -> Action
(18, 12, 5), -- Inception -> Adventure
(19, 12, 6), -- Inception -> Sci-Fi
(20, 13, 5), -- The Lord of the Rings: The Fellowship of the Ring -> Adventure
(21, 13, 9), -- The Lord of the Rings: The Fellowship of the Ring -> Fantasy
(22, 14, 3), -- Star Wars: Episode V - The Empire Strikes Back -> Action
(23, 14, 6), -- Star Wars: Episode V - The Empire Strikes Back -> Sci-Fi
(24, 15, 3), -- The Matrix -> Action
(25, 15, 6), -- The Matrix -> Sci-Fi
(26, 16, 1), -- Goodfellas -> Drama
(27, 16, 2), -- Goodfellas -> Crime
(28, 17, 1), -- One Flew Over the Cuckoo's Nest -> Drama
(29, 18, 5), -- Seven Samurai -> Adventure
(30, 19, 4), -- Se7en -> Thriller
(31, 19, 1), -- Se7en -> Drama
(32, 20, 1), -- It's a Wonderful Life -> Drama
(33, 21, 4), -- The Silence of the Lambs -> Thriller
(34, 21, 10),-- The Silence of the Lambs -> Mystery
(35, 22, 2), -- City of God -> Crime
(36, 22, 1), -- City of God -> Drama
(37, 23, 11),-- Saving Private Ryan -> War
(38, 23, 1), -- Saving Private Ryan -> Drama
(39, 24, 5), -- Interstellar -> Adventure
(40, 24, 6), -- Interstellar -> Sci-Fi
(41, 25, 1), -- The Green Mile -> Drama
(42, 26, 1), -- Life Is Beautiful -> Drama
(43, 26, 15),-- Life Is Beautiful -> Romance
(44, 27, 3), -- Star Wars: Episode IV - A New Hope -> Action
(45, 27, 6), -- Star Wars: Episode IV - A New Hope -> Sci-Fi
(46, 28, 3), -- Terminator 2: Judgment Day -> Action
(47, 28, 6), -- Terminator 2: Judgment Day -> Sci-Fi
(48, 29, 3), -- Back to the Future -> Action
(49, 29, 6), -- Back to the Future -> Sci-Fi
(50, 30, 12),-- Spirited Away -> Animation
(51, 30, 9), -- Spirited Away -> Fantasy
(52, 31, 1), -- The Pianist -> Drama
(53, 32, 1), -- The Departed -> Drama
(54, 32, 2), -- The Departed -> Crime
(55, 33, 3), -- Gladiator -> Action
(56, 33, 5), -- Gladiator -> Adventure
(57, 34, 10),-- The Prestige -> Mystery
(58, 34, 1), -- The Prestige -> Drama
(59, 35, 12),-- The Lion King -> Animation
(60, 35, 14),-- The Lion King -> Family
(61, 36, 4), -- Memento -> Thriller
(62, 36, 1), -- Memento -> Drama
(63, 37, 1), -- Apocalypse Now -> Drama
(64, 37, 11),-- Apocalypse Now -> War
(65, 38, 4), -- Alien -> Thriller
(66, 38, 6), -- Alien -> Sci-Fi
(67, 39, 1), -- The Great Dictator -> Drama
(68, 39, 13),-- The Great Dictator -> Comedy
(69, 40, 1), -- Sunset Blvd. -> Drama
(70, 40, 10),-- Sunset Blvd. -> Mystery
(71, 41, 13),-- Dr. Strangelove -> Comedy
(72, 41, 16),-- Dr. Strangelove -> Horror
(73, 42, 16),-- The Shining -> Horror
(74, 43, 12),-- WALL·E -> Animation
(75, 43, 14),-- WALL·E -> Family
(76, 44, 1), -- American Beauty -> Drama
(77, 45, 3), -- The Dark Knight Rises -> Action
(78, 45, 1), -- The Dark Knight Rises -> Drama
(79, 46, 4), -- Oldboy -> Thriller
(80, 47, 9), -- Princess Mononoke -> Fantasy
(81, 47, 12),-- Princess Mononoke -> Animation
(82, 48, 1), -- Once Upon a Time in America -> Drama
(83, 49, 10),-- Witness for the Prosecution -> Mystery
(84, 49, 1), -- Witness for the Prosecution -> Drama
(85, 50, 11);-- Das Boot -> War

-- %%
SELECT g.GenreName 
FROM Movies m
JOIN MovieGenres mg ON m.MovieID = mg.MovieID
JOIN Genres g ON mg.GenreID = g.GenreID
WHERE m.Title = 'Inception';
-- Out:
-- +-----------+
-- | GenreName |
-- +-----------+
-- | Action    |
-- +-----------+
-- | Adventure |
-- +-----------+
-- | Sci-Fi    |
-- +-----------+

-- %%
SELECT Title, Duration 
FROM Movies 
ORDER BY Duration ASC 
LIMIT 5;
-- Out:
-- +----------------------------------------------------------------------+----------+
-- | Title                                                                | Duration |
-- +----------------------------------------------------------------------+----------+
-- | The Lion King                                                        | 88       |
-- +----------------------------------------------------------------------+----------+
-- | Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb | 95       |
-- +----------------------------------------------------------------------+----------+
-- | 12 Angry Men                                                         | 96       |
-- +----------------------------------------------------------------------+----------+
-- | WALL·E                                                              | 98       |
-- +----------------------------------------------------------------------+----------+
-- ...

-- %%
SELECT g.GenreName, AVG(m.Duration) AS AvgDuration 
FROM Genres g
JOIN MovieGenres mg ON g.GenreID = mg.GenreID
JOIN Movies m ON mg.MovieID = m.MovieID
GROUP BY g.GenreName 
ORDER BY AvgDuration DESC;
-- Out:
-- +-----------+------------------+
-- | GenreName | AvgDuration      |
-- +-----------+------------------+
-- | Western   | 178.0            |
-- +-----------+------------------+
-- | Adventure | 176.333333333333 |
-- +-----------+------------------+
-- | Crime     | 158.571428571429 |
-- +-----------+------------------+
-- | War       | 155.0            |
-- +-----------+------------------+
-- | Drama     | 147.964285714286 |
-- +-----------+------------------+
-- | Fantasy   | 145.666666666667 |
-- +-----------+------------------+
-- | Action    | 139.222222222222 |
-- +-----------+------------------+
-- | Sci-Fi    | 133.5            |
-- +-----------+------------------+
-- | Horror    | 120.5            |
-- +-----------+------------------+
-- | Thriller  | 119.0            |
-- +-----------+------------------+
-- | Mystery   | 118.5            |
-- +-----------+------------------+
-- | Romance   | 116.0            |
-- +-----------+------------------+
-- ...

-- %%
SELECT Director, COUNT(MovieID) AS MovieCount 
FROM Movies 
GROUP BY Director 
HAVING COUNT(MovieID) > 1 
ORDER BY MovieCount DESC;
-- Out:
-- +----------------------+------------+
-- | Director             | MovieCount |
-- +----------------------+------------+
-- | Christopher Nolan    | 6          |
-- +----------------------+------------+
-- | Francis Ford Coppola | 3          |
-- +----------------------+------------+
-- | Steven Spielberg     | 2          |
-- +----------------------+------------+
-- | Stanley Kubrick      | 2          |
-- +----------------------+------------+
-- | Sergio Leone         | 2          |
-- +----------------------+------------+
-- | Robert Zemeckis      | 2          |
-- +----------------------+------------+
-- | Ridley Scott         | 2          |
-- +----------------------+------------+
-- | Peter Jackson        | 2          |
-- +----------------------+------------+
-- | Martin Scorsese      | 2          |
-- +----------------------+------------+
-- | Hayao Miyazaki       | 2          |
-- +----------------------+------------+
-- | Frank Darabont       | 2          |
-- ...

-- %%
SELECT m.Title 
FROM Movies m
JOIN MovieGenres mg1 ON m.MovieID = mg1.MovieID
JOIN Genres g1 ON mg1.GenreID = g1.GenreID
JOIN MovieGenres mg2 ON m.MovieID = mg2.MovieID
JOIN Genres g2 ON mg2.GenreID = g2.GenreID
WHERE g1.GenreName = 'Action' AND g2.GenreName = 'Sci-Fi';
-- Out:
-- +------------------------------------------------+
-- | Title                                          |
-- +------------------------------------------------+
-- | Inception                                      |
-- +------------------------------------------------+
-- | Star Wars: Episode V - The Empire Strikes Back |
-- +------------------------------------------------+
-- | The Matrix                                     |
-- +------------------------------------------------+
-- | Star Wars: Episode IV - A New Hope             |
-- +------------------------------------------------+
-- | Terminator 2: Judgment Day                     |
-- +------------------------------------------------+
-- | Back to the Future                             |
-- +------------------------------------------------+

-- %%
SELECT g.GenreName, COUNT(mg.MovieID) AS MovieCount 
FROM Genres g
JOIN MovieGenres mg ON g.GenreID = mg.GenreID
GROUP BY g.GenreName 
ORDER BY MovieCount DESC;
-- Out:
-- +-----------+------------+
-- | GenreName | MovieCount |
-- +-----------+------------+
-- | Drama     | 28         |
-- +-----------+------------+
-- | Action    | 9          |
-- +-----------+------------+
-- | Sci-Fi    | 8          |
-- +-----------+------------+
-- | Crime     | 7          |
-- +-----------+------------+
-- | Adventure | 6          |
-- +-----------+------------+
-- | Thriller  | 5          |
-- +-----------+------------+
-- | Mystery   | 4          |
-- +-----------+------------+
-- | Animation | 4          |
-- +-----------+------------+
-- | War       | 3          |
-- +-----------+------------+
-- | Fantasy   | 3          |
-- +-----------+------------+
-- | Horror    | 2          |
-- +-----------+------------+
-- | Family    | 2          |
-- +-----------+------------+
-- | Comedy    | 2          |
-- +-----------+------------+
-- | Western   | 1          |
-- +-----------+------------+
-- | Romance   | 1          |
-- +-----------+------------+

-- %%
SELECT m.Title 
FROM Movies m
JOIN MovieGenres mg ON m.MovieID = mg.MovieID
JOIN Genres g ON mg.GenreID = g.GenreID
WHERE g.GenreName = 'Drama';
-- Out:
-- +-----------------------------------------------+
-- | Title                                         |
-- +-----------------------------------------------+
-- | The Shawshank Redemption                      |
-- +-----------------------------------------------+
-- | The Godfather                                 |
-- +-----------------------------------------------+
-- | The Godfather Part II                         |
-- +-----------------------------------------------+
-- | 12 Angry Men                                  |
-- +-----------------------------------------------+
-- | Schindler's List                              |
-- +-----------------------------------------------+
-- | The Lord of the Rings: The Return of the King |
-- +-----------------------------------------------+
-- | Pulp Fiction                                  |
-- +-----------------------------------------------+
-- | Fight Club                                    |
-- ...

-- %%
SELECT Title 
FROM Movies 
WHERE Director = 'Christopher Nolan';
-- Out:
-- +-----------------------+
-- | Title                 |
-- +-----------------------+
-- | The Dark Knight       |
-- +-----------------------+
-- | Inception             |
-- +-----------------------+
-- | Interstellar          |
-- +-----------------------+
-- | The Prestige          |
-- +-----------------------+
-- | Memento               |
-- +-----------------------+
-- | The Dark Knight Rises |
-- +-----------------------+

-- %%
SELECT Title, Duration 
FROM Movies 
ORDER BY Duration DESC 
LIMIT 5;
-- Out:
-- +-----------------------------------------------+----------+
-- | Title                                         | Duration |
-- +-----------------------------------------------+----------+
-- | Once Upon a Time in America                   | 229      |
-- +-----------------------------------------------+----------+
-- | Seven Samurai                                 | 207      |
-- +-----------------------------------------------+----------+
-- | The Godfather Part II                         | 202      |
-- +-----------------------------------------------+----------+
-- | The Lord of the Rings: The Return of the King | 201      |
-- +-----------------------------------------------+----------+
-- | Schindler's List                              | 195      |
-- +-----------------------------------------------+----------+

-- %%
SELECT Title, ReleaseYear 
FROM Movies 
WHERE ReleaseYear > 2000 
ORDER BY ReleaseYear ASC;
-- Out:
-- +---------------------------------------------------+-------------+
-- | Title                                             | ReleaseYear |
-- +---------------------------------------------------+-------------+
-- | The Lord of the Rings: The Fellowship of the Ring | 2001        |
-- +---------------------------------------------------+-------------+
-- | Spirited Away                                     | 2001        |
-- +---------------------------------------------------+-------------+
-- | City of God                                       | 2002        |
-- +---------------------------------------------------+-------------+
-- | The Pianist                                       | 2002        |
-- +---------------------------------------------------+-------------+
-- | The Lord of the Rings: The Return of the King     | 2003        |
-- +---------------------------------------------------+-------------+
-- | Oldboy                                            | 2003        |
-- ...
